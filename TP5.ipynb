# %% [markdown]
# # Koopman operator learning, a toy case: Duffing oscillator
#
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**

# %% [markdown]
# The aim of this notebook is to describe the dynamics of a non-linear dynamical system by means of the Koopman theory.
#
# ## Introduction
#
# We consider a quantity $x$ (a vector) which evolves with time, following a dynamical system. Think for example of the joint location of the planets in our solar system, which follows the law of gravitation.
#
# Formally, given an initial state $x(t=0) \in \mathbb{R}^n$ at time $t=0$, the time evolution of $x$ is governed by the following dynamical system:
# $$
# \dot{x}(t) = f(x(t)) \quad \text(1)
# $$
#
# where $\dot{x}(t) := \frac{dx(t)}{dt}$ is the temporal derivative, and $f:\mathbb{R}^n \rightarrow \mathbb{R}^n$ is a given map describing the dynamics.
#
# For a given $f$, it is not always possible to solve the differential equation (1) analytically. For this reason, instead, numerical schemes are usually employed, to integrate in time $t$ the equation (1), so as to propagate the initial condition $x(0)$ up to a desired time $T$; think of $x(T) = x(0) + \int_{t=0}^{T} f(x(t)) dt$. The discretization in time of eq (1) or of the integral introduces numerical approximations, and yields estimates of $x(T)$ of various quality depending on the discretization scheme.
#
# In the field of numerical simulations, discretization schemes have been studied for a long time, and numerical solvers already exist to provide good estimates of integrals (far better than with the naive discretization $x_{k+\delta} = x_k + \delta\,f(x_k)$ for a discrete time increment $\delta$, which induces a $O(\delta^2)$ error at each time step).
#
# The goal of this practical session is to make use of such numerical solvers to improve the learning of dynamical systems with neural networks.

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm

from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd

# arrange the dataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Duffing oscillator
#
# As a toy example, we consider the Duffing oscillator, where the state $x = (x_1, x_2) \in \mathbb{R}^2$ follows the dynamical system described by the following ODEs:
#
# $$
# \dot{x}_1 = x_2\\
# \dot{x}_2 = x_1 - x_1^3
# $$
#
# To integrate in time the ODEs, a 4th order Runge-Kutta scheme can be used.

# %%
def duffing(array_x: np.ndarray) -> np.ndarray:
    array_dx = np.zeros(array_x.shape)
    array_dx[0] = array_x[1]
    array_dx[1] = array_x[0] - array_x[0] ** 3
    return array_dx

# %%
t_max = 500  # Time-horizon integration
n_iter = 5000  # Number of time steps integration
n_initial_conditions = 60  # Number of initial conditions

dim_system = 2

# Generate initial conditions
matrix_x0 = (np.random.rand(n_initial_conditions, dim_system) - 0.5) * 4
array_t = np.linspace(0, t_max, n_iter)
array3d_xt = np.zeros((matrix_x0.shape[0], matrix_x0.shape[1], n_iter))

for i in tqdm(range(matrix_x0.shape[0])):
    # Lambda function is used as solve_ivp requires a function of the form f(t, x)
    ode_result = solve_ivp(lambda _t, array_x: duffing(array_x),
                           [0, t_max],
                           matrix_x0[i],
                           method='RK45',
                           t_eval=array_t)

    array3d_xt[i, :] = ode_result.y
# Out:
# 100%|██████████| 60/60 [00:10<00:00,  5.69it/s]

# %% [markdown]
# The following plot shows trajectories for different initial conditions:

# %%
fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(131)
cm = plt.get_cmap("tab10")
print(cm)
for i in range(10):
    ax.plot(array3d_xt[i, 0, :], array3d_xt[i, 1, :], lw=0.5, color=cm(i))
    ax.plot(array3d_xt[i, 0, 0], array3d_xt[i, 1, 0], 'o', lw=1.5, color=cm(i))  #initial condition
ax.set_xlabel('$x_1$', fontsize=20)
ax.set_ylabel('$x_2$', fontsize=20)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x000001D5FDDE9B10>

# %% [markdown]
# ## The Koopman operator
# ### Discontinuous in time case
# Given the discrete non-linear dynamical system
#
# $$
# x_{k+1} = F(x_k)
# $$
#
# where $F$ might be the $\delta$-discretised flow map of the continuous dynamical system in eq (1) given by
#
# $$
# x_{k+1} = F(x_k) := x_k + \int_{k}^{k + \delta} f(x(s))ds
# $$
#
# and $X = (x_k)_{k = 0}^N$ the discrete time series of the system state.
#
#
# The _Koopman_ theory states that there exists an infinite-dimensional linear operator $\mathcal{K}$ that advances in time all observable functions $(g_i)_{i = 1}^m$ given by $g_i: \mathbb{R}^n \rightarrow \mathbb{R}$
#
# $$
# \mathcal{K} g_i(x) = g_i \circ F(x)
# $$
#
# This way, the non-linear dynamics of $x$, described by $F$, can be turned into a **linear** dynamical system, described by $\mathcal{K}$, acting on another representation space, formed by the observable quantities $g_i(x)$.
#
# Indeed, let $g_i$ be an observable function and denoting ${g_i}_k := g_i(x_k)$, using the previous equation, the time evolution of the observables is given by
#
# $$
# {g_i}_{k+1} = g_i(x_{k+1}) = g_i(F(x_k)) = g_i \circ F(x_k) = \mathcal{K} g_i(x_k) = \mathcal{K} {g_i}_k
# $$
#
# then, the linearised dynamics of the observables is given by the following equation
#
# $$
# {g_i}_{k+1} = \mathcal{K} {g_i}_k
# $$
#
#
# It is then sufficient to find a function $g: \mathbb{R}^n \rightarrow \mathbb{R}^m$ with $m \gg n$ that embeds the state $x$ into a "larger enough" dimensional space $m$ such that the linear operator $\mathcal{K}$ can be inferred by a matrix $\mathbf{K} \in \mathbb{R}^{m \times m}$.
#
# To project back the dynamics from the Koopman space ($\mathbb{R}^m$, where $g(x)$ lives) to the phase space ($\mathbb{R}^n$, where $x$ lives), a supplementary function $\varphi: \mathbb{R}^m \rightarrow \mathbb{R}^n$ is needed. Going from $x$ to the Koopman space and back yields $\varphi \text{ o  } g = $ Id.
#
# Under this condition, the functions $g$, $\varphi$ and $\mathbf{K}$ can be parametrized $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{K}_{\phi}$, and the parameters $\theta$, $\rho$ and $\phi$ can be learned minimizing suitable loss functions.
#
# For this purpose, given a time series $X = \{x_k | k = 1 \ldots N \}$, the following conditions hold:
#
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
#      $$
#
# The last three errors can be used as loss functions to train three different neural networks. These different neural networks compose our architecture that can be summarized as in the following sketch:

# %% [markdown]
# ![architecture](./architecture.png)

# %%
# Flatten the trajectories w.r.t. initial conditions 
# and only keep data in the form of (dim_system, n_iter * n_initial_conditions)
matrix_x_data = array3d_xt[:, :, :-1].swapaxes(0, 1).reshape(2, -1).T
matrix_x_next_data = array3d_xt[:, :, 1:].swapaxes(0, 1).reshape(2, -1).T

(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x_data,
                                             matrix_x_next_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type('torch.DoubleTensor')

batch_size = 2000  # data per batch

tensor2d_x_data_train = torch.from_numpy(matrix_x_data_train).to(device)
tensor2d_x_next_data_train = torch.from_numpy(matrix_x_next_data_train).to(device)
tensor2d_x_data_test = torch.from_numpy(matrix_x_data_test).to(device)
tensor2d_x_next_data_test = torch.from_numpy(matrix_x_next_data_test).to(device)

torch_dataset_train = TensorDataset(tensor2d_x_data_train,
                                    tensor2d_x_next_data_train)

torch_dataset_test = TensorDataset(tensor2d_x_data_test,
                                   tensor2d_x_next_data_test)

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)

# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER) 
output_dim = 30  # dimension in Koopman space

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x: torch.Tensor):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim: int, hidden_layer: int, output_dim: int):
        super().__init__()
        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]
        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.Encoder(tensor2d_x)
        return self.Decoder(tensor2d_x)

# %% [markdown]
# The Koopman operator $\mathbf{K}$ (which is linear, and thus a matrix) must have a [spectral radius](https://en.wikipedia.org/wiki/Spectral_radius) $\rho(\mathbf{K})\le 1$. Such condition will provide a stable -or at least a marginally stable- Koopman operator. To fulfill this requirement, we might leverage on the Perron-Frobenius theorem.
#
# The Perron-Frobenius th. states: if $\mathbf{K}$ is a $m \times m$ positive matrix i.e. $k_{ij} > 0$ for $1 \le i,j \le m$, then the following inequality holds:
#
# $$
# \min_i \sum_j k_{ij} \le \rho(\mathbf{K}) \le \max_i \sum_j k_{ij}
# $$

# %% [markdown]
# **Question 1.** : Complete the `KoopmanModule` class to enforce $\rho(\mathbf{K})\le 1$, using the Perron-Frobenius theorem. Check that the initialization fulfills this property.

# %%
class KoopmanOperator(nn.Module):
    def __init__(self, koopman_operator_dim: int):
        super().__init__()
        self.koopman_operator_dim = koopman_operator_dim
        # TODO: Complete the KoopmanOperator class
        self.koopman_matrix = torch.randn(koopman_operator_dim, koopman_operator_dim)
        self.register_parameter(name='weights', param=torch.nn.Parameter(self.koopman_matrix))

                

    def forward(self, tensor2d_x: torch.Tensor):
        # First dimension of tensor2d_x is the batch size
        if tensor2d_x.shape[1] != self.koopman_operator_dim:
            sys.exit(f'Wrong Input Features. Please use tensor'
                     f' with {self.koopman_operator_dim} Input Features')
        
        max_colsum = np.array(self.koopman_matrix).sum(axis=1).max()
        if max_colsum > 1:
            self.koopman_matrix = self.koopman_matrix / max_colsum

        # Forward pass
        tensor2d_x = torch.matmul(tensor2d_x, self.koopman_matrix)
        return tensor2d_x
    





dim_observable = 10
koopman_operator = KoopmanOperator(dim_observable)

# %%
max_colsum = np.array(koopman_operator.koopman_matrix).sum(axis=1).max()
if max_colsum > 1:
    koopman_operator.koopman_matrix = koopman_operator.koopman_matrix / max_colsum

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
koopman_operator = KoopmanOperator(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %%
learning_rate_autoencoder = 0.0001
learning_rate_koopman = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder)

optimiser_koopman = torch.optim.Adam(koopman_operator.parameters(),
                                     lr=learning_rate_koopman)

# %% [markdown]
# **Question 2.** : Define a function to compute the loss to be minimized. It should at least include the 3 terms listed above:
# - Reconstruction error
# - Prediction error in the Koopman space
# - Prediction error in the phase space
#
# Because the different objectives outlined by these losses may compete, the training can be difficult. You may try different variations on these losses and comment your findings. In order to improve the training process, one can for instance:
# - Add a multiplicative factor in front of each loss component, to balance their importance; how the scales of different losses are related?
# - We can refine the loss acting upon the latent space, by using a variational autoencoder approach. This is similar to the Gaussian likelihood used in the first practical (TD1). We want the prediction in the latent space (i.e. the Koopman space) to be a normal distribution $\mathcal{N}(0, 1)$ . Add a corresponding loss for the latent space. Difference to 0 mean and 1 standard deviation must be thus included in the loss;
# - Freeze the gradients of one part of the network, for instance the encoder, for one specific objective, using the [`requires_grad`](https://pytorch.org/docs/stable/generated/torch.Tensor.requires_grad_.html) property. For instance:
# ```python
# criterion = nn.MSELoss()
# ...
# # Compute one part loss_l of the total loss
# # First deactivate gradient computation for irrelevant parts of the architecture
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = False
# loss_l = criterion(pred, target)
# # Restore the gradient computation
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = True
# ...
# total_loss = loss_1 + ... + loss_l + ...
# ```

# %%
# TODO: Implement the loss function here
# HINT: See the training process below to identify the different components of the loss
def loss_koopman(tensor2d_x: torch.Tensor,
                 tensor2d_x_next: torch.Tensor,
                 tensor2d_decoded_x: torch.Tensor,
                 tensor2d_observable_next: torch.Tensor,
                 tensor2d_koopman_observable_next: torch.Tensor,
                 tensor2d_predict_x_next: torch.Tensor):

    # TODO: Implement the loss function here
    criterion = nn.MSELoss()
    coef = [1, 1, 1]

    # Compute one part loss_l of the total loss
    # First deactivate gradient computation for encoder
    for p in autoencoder.encoder.parameters():
        p.requires_grad = False
    
    # Compute the loss
    reconstruction_loss = criterion(tensor2d_decoded_x, tensor2d_x)
    koopman_loss = criterion(tensor2d_koopman_observable_next, tensor2d_observable_next)
    phase_loss = criterion(tensor2d_predict_x_next, tensor2d_x_next)
    
    # Restore the gradient computation
    for p in autoencoder.encoder.parameters():
        p.requires_grad = True

    # Total loss
    total_loss = coef[0]*reconstruction_loss + coef[1]*koopman_loss + coef[2]*phase_loss

    return total_loss, reconstruction_loss, koopman_loss, phase_loss

# %% [markdown]
# 1.   Reconstruction error
# $$
# \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
# $$
# 2.   Prediction error in Koopman space
# $$
# \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
# $$
# 3.   Prediction error in the phase space
# $$
# \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
# $$

# %% [markdown]
# **Question 3.**: The following cell executes the training loop. You can modify it in order to display the different intermediate losses computed in the function `LOSS` above. How do they evolve in time? Justify your final choice.

# %%
n_batch = len(train_dataloader)
n_epoch = 100  # To be tuned 

for epoch in range(n_epoch):
    autoencoder.train()
    koopman_operator.train()
    total_train_loss = 0
    total_loss1, total_loss2, total_loss3, total_loss4 = 0, 0, 0, 0
    for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
        tensor2d_batch_x = tensor2d_batch_x.to(device)
        tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

        optimiser_autoencoder.zero_grad()
        optimiser_koopman.zero_grad()

        tensor2d_observable = autoencoder.encoder(tensor2d_batch_x)
        tensor2d_observable_next = autoencoder.encoder(tensor2d_batch_x_next)

        tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)

        tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)

        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)

        tensor_loss_val, tensor_loss1, tensor_loss2, tensor_loss3 = loss_koopman(
            tensor2d_batch_x,
            tensor2d_batch_x_next,
            tensor2d_decoded_x,
            tensor2d_observable_next,
            tensor2d_koopman_observable_next,
            tensor2d_predict_x_next
        )

        tensor_loss_val.backward()
        optimiser_autoencoder.step()
        optimiser_koopman.step()

        if epoch % 1 == 0:
            total_train_loss += tensor_loss_val.item()
            total_loss1 += tensor_loss1.item()
            total_loss2 += tensor_loss2.item()
            total_loss3 += tensor_loss3.item()

    if epoch % 1 == 0:
        print(
            f'Epoch: {epoch}, Loss: {total_train_loss:.4f}, '
            f'Reconstruction Loss: {total_loss1:.4f}, '
            f'Koopman Loss: {total_loss2:.4f}, '
            f'Phase Loss: {total_loss3:.4f}'
        )

    if epoch % 10 == 0:
        autoencoder.eval()
        koopman_operator.eval()
        tensor_loss_val = None
        with torch.no_grad():
            total_test_loss = 0
            total_test_loss1, total_test_loss2, total_test_loss3 = 0, 0, 0
            for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                tensor2d_batch_x = tensor2d_batch_x.to(device)
                tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                tensor2d_observable = \
                    autoencoder.encoder(tensor2d_batch_x)
                tensor2d_observable_next = \
                    autoencoder.encoder(tensor2d_batch_x_next)
                tensor2d_decoded_x = \
                    autoencoder.decoder(tensor2d_observable)
                tensor2d_koopman_observable_next = \
                    koopman_operator(tensor2d_observable)
                tensor2d_predict_x_next = \
                    autoencoder.decoder(tensor2d_koopman_observable_next)

                tensor_loss_val, tensor_loss1, tensor_loss2, tensor_loss3 = loss_koopman(
                    tensor2d_batch_x,
                    tensor2d_batch_x_next,
                    tensor2d_decoded_x,
                    tensor2d_observable_next,
                    tensor2d_koopman_observable_next,
                    tensor2d_predict_x_next
                )

                total_test_loss += tensor_loss_val.item()
                total_test_loss1 += tensor_loss1.item()
                total_test_loss2 += tensor_loss2.item()
                total_test_loss3 += tensor_loss3.item()

            print('-' * 50, 'TEST', '-' * 50)
            print(
                f'Epoch: {epoch}, Loss: {total_test_loss:.4f}, '
                f'Reconstruction Loss: {total_test_loss1:.4f}, '
                f'Koopman Loss: {total_test_loss2:.4f}, '
                f'Phase Loss: {total_test_loss3:.4f}'
            )
            print('-' * 106)
# Out:
# Epoch: 0, Loss: 410.3042, Reconstruction Loss: 203.5077, Koopman Loss: 2.6261, Phase Loss: 204.1704
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 0, Loss: 101.3903, Reconstruction Loss: 50.2636, Koopman Loss: 0.5017, Phase Loss: 50.6250
# ----------------------------------------------------------------------------------------------------------
# Epoch: 1, Loss: 393.4691, Reconstruction Loss: 192.6484, Koopman Loss: 2.4340, Phase Loss: 198.3867
# Epoch: 2, Loss: 320.5671, Reconstruction Loss: 143.5294, Koopman Loss: 9.7824, Phase Loss: 167.2554
# Epoch: 3, Loss: 251.5364, Reconstruction Loss: 112.5337, Koopman Loss: 12.8686, Phase Loss: 126.1341
# Epoch: 4, Loss: 223.1546, Reconstruction Loss: 101.7132, Koopman Loss: 8.8856, Phase Loss: 112.5558
# Epoch: 5, Loss: 177.3978, Reconstruction Loss: 71.3721, Koopman Loss: 10.2689, Phase Loss: 95.7568
# Epoch: 6, Loss: 101.7562, Reconstruction Loss: 34.8159, Koopman Loss: 14.5878, Phase Loss: 52.3525
# Epoch: 7, Loss: 64.8664, Reconstruction Loss: 23.1801, Koopman Loss: 13.0481, Phase Loss: 28.6382
# Epoch: 8, Loss: 46.0554, Reconstruction Loss: 16.2499, Koopman Loss: 10.2328, Phase Loss: 19.5727
# Epoch: 9, Loss: 33.2243, Reconstruction Loss: 11.1458, Koopman Loss: 8.2448, Phase Loss: 13.8337
# Epoch: 10, Loss: 25.2219, Reconstruction Loss: 8.1855, Koopman Loss: 6.6083, Phase Loss: 10.4280
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 10, Loss: 5.6060, Reconstruction Loss: 1.8110, Koopman Loss: 1.4694, Phase Loss: 2.3256
# ----------------------------------------------------------------------------------------------------------
# Epoch: 11, Loss: 20.3098, Reconstruction Loss: 6.5910, Koopman Loss: 5.2769, Phase Loss: 8.4420
# Epoch: 12, Loss: 16.9855, Reconstruction Loss: 5.5833, Koopman Loss: 4.2463, Phase Loss: 7.1559
# Epoch: 13, Loss: 14.4797, Reconstruction Loss: 4.8043, Koopman Loss: 3.4699, Phase Loss: 6.2056
# Epoch: 14, Loss: 12.4595, Reconstruction Loss: 4.1361, Koopman Loss: 2.8816, Phase Loss: 5.4418
# Epoch: 15, Loss: 10.7588, Reconstruction Loss: 3.5377, Koopman Loss: 2.4300, Phase Loss: 4.7911
# Epoch: 16, Loss: 9.2911, Reconstruction Loss: 2.9937, Koopman Loss: 2.0788, Phase Loss: 4.2187
# Epoch: 17, Loss: 7.9986, Reconstruction Loss: 2.4988, Koopman Loss: 1.8011, Phase Loss: 3.6988
# Epoch: 18, Loss: 6.8492, Reconstruction Loss: 2.0506, Koopman Loss: 1.5790, Phase Loss: 3.2197
# Epoch: 19, Loss: 5.8257, Reconstruction Loss: 1.6570, Koopman Loss: 1.3996, Phase Loss: 2.7691
# Epoch: 20, Loss: 4.9211, Reconstruction Loss: 1.3242, Koopman Loss: 1.2517, Phase Loss: 2.3451
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 20, Loss: 1.1254, Reconstruction Loss: 0.2929, Koopman Loss: 0.2970, Phase Loss: 0.5355
# ----------------------------------------------------------------------------------------------------------
# Epoch: 21, Loss: 4.1238, Reconstruction Loss: 1.0469, Koopman Loss: 1.1291, Phase Loss: 1.9478
# Epoch: 22, Loss: 3.4239, Reconstruction Loss: 0.8185, Koopman Loss: 1.0263, Phase Loss: 1.5790
# Epoch: 23, Loss: 2.8221, Reconstruction Loss: 0.6373, Koopman Loss: 0.9397, Phase Loss: 1.2451
# Epoch: 24, Loss: 2.3361, Reconstruction Loss: 0.5068, Koopman Loss: 0.8665, Phase Loss: 0.9628
# Epoch: 25, Loss: 1.9795, Reconstruction Loss: 0.4248, Koopman Loss: 0.8049, Phase Loss: 0.7498
# Epoch: 26, Loss: 1.7343, Reconstruction Loss: 0.3767, Koopman Loss: 0.7522, Phase Loss: 0.6053
# Epoch: 27, Loss: 1.5618, Reconstruction Loss: 0.3447, Koopman Loss: 0.7059, Phase Loss: 0.5111
# Epoch: 28, Loss: 1.4295, Reconstruction Loss: 0.3190, Koopman Loss: 0.6645, Phase Loss: 0.4460
# Epoch: 29, Loss: 1.3197, Reconstruction Loss: 0.2943, Koopman Loss: 0.6270, Phase Loss: 0.3984
# Epoch: 30, Loss: 1.2245, Reconstruction Loss: 0.2717, Koopman Loss: 0.5927, Phase Loss: 0.3601
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 30, Loss: 0.2974, Reconstruction Loss: 0.0667, Koopman Loss: 0.1445, Phase Loss: 0.0862
# ----------------------------------------------------------------------------------------------------------
# Epoch: 31, Loss: 1.1411, Reconstruction Loss: 0.2515, Koopman Loss: 0.5611, Phase Loss: 0.3286
# Epoch: 32, Loss: 1.0645, Reconstruction Loss: 0.2316, Koopman Loss: 0.5318, Phase Loss: 0.3011
# Epoch: 33, Loss: 0.9963, Reconstruction Loss: 0.2148, Koopman Loss: 0.5044, Phase Loss: 0.2771
# Epoch: 34, Loss: 0.9341, Reconstruction Loss: 0.1995, Koopman Loss: 0.4790, Phase Loss: 0.2556
# Epoch: 35, Loss: 0.8768, Reconstruction Loss: 0.1850, Koopman Loss: 0.4551, Phase Loss: 0.2366
# Epoch: 36, Loss: 0.8245, Reconstruction Loss: 0.1723, Koopman Loss: 0.4328, Phase Loss: 0.2194
# Epoch: 37, Loss: 0.7771, Reconstruction Loss: 0.1613, Koopman Loss: 0.4118, Phase Loss: 0.2041
# Epoch: 38, Loss: 0.7330, Reconstruction Loss: 0.1507, Koopman Loss: 0.3921, Phase Loss: 0.1902
# Epoch: 39, Loss: 0.6926, Reconstruction Loss: 0.1414, Koopman Loss: 0.3737, Phase Loss: 0.1776
# Epoch: 40, Loss: 0.6558, Reconstruction Loss: 0.1330, Koopman Loss: 0.3563, Phase Loss: 0.1665
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 40, Loss: 0.1602, Reconstruction Loss: 0.0327, Koopman Loss: 0.0870, Phase Loss: 0.0404
# ----------------------------------------------------------------------------------------------------------
# Epoch: 41, Loss: 0.6225, Reconstruction Loss: 0.1261, Koopman Loss: 0.3398, Phase Loss: 0.1565
# Epoch: 42, Loss: 0.5925, Reconstruction Loss: 0.1202, Koopman Loss: 0.3245, Phase Loss: 0.1478
# Epoch: 43, Loss: 0.5631, Reconstruction Loss: 0.1135, Koopman Loss: 0.3101, Phase Loss: 0.1395
# Epoch: 44, Loss: 0.5373, Reconstruction Loss: 0.1085, Koopman Loss: 0.2965, Phase Loss: 0.1323
# Epoch: 45, Loss: 0.5134, Reconstruction Loss: 0.1038, Koopman Loss: 0.2837, Phase Loss: 0.1259
# Epoch: 46, Loss: 0.4905, Reconstruction Loss: 0.0991, Koopman Loss: 0.2717, Phase Loss: 0.1198
# Epoch: 47, Loss: 0.4696, Reconstruction Loss: 0.0949, Koopman Loss: 0.2603, Phase Loss: 0.1145
# Epoch: 48, Loss: 0.4513, Reconstruction Loss: 0.0919, Koopman Loss: 0.2496, Phase Loss: 0.1098
# Epoch: 49, Loss: 0.4323, Reconstruction Loss: 0.0876, Koopman Loss: 0.2395, Phase Loss: 0.1052
# Epoch: 50, Loss: 0.4159, Reconstruction Loss: 0.0847, Koopman Loss: 0.2300, Phase Loss: 0.1012
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 50, Loss: 0.1018, Reconstruction Loss: 0.0206, Koopman Loss: 0.0565, Phase Loss: 0.0246
# ----------------------------------------------------------------------------------------------------------
# Epoch: 51, Loss: 0.3989, Reconstruction Loss: 0.0806, Koopman Loss: 0.2211, Phase Loss: 0.0972
# Epoch: 52, Loss: 0.3839, Reconstruction Loss: 0.0777, Koopman Loss: 0.2126, Phase Loss: 0.0936
# Epoch: 53, Loss: 0.3700, Reconstruction Loss: 0.0750, Koopman Loss: 0.2045, Phase Loss: 0.0905
# Epoch: 54, Loss: 0.3562, Reconstruction Loss: 0.0720, Koopman Loss: 0.1969, Phase Loss: 0.0874
# Epoch: 55, Loss: 0.3446, Reconstruction Loss: 0.0701, Koopman Loss: 0.1897, Phase Loss: 0.0848
# Epoch: 56, Loss: 0.3319, Reconstruction Loss: 0.0672, Koopman Loss: 0.1829, Phase Loss: 0.0819
# Epoch: 57, Loss: 0.3227, Reconstruction Loss: 0.0661, Koopman Loss: 0.1765, Phase Loss: 0.0800
# Epoch: 58, Loss: 0.3098, Reconstruction Loss: 0.0622, Koopman Loss: 0.1706, Phase Loss: 0.0770
# Epoch: 59, Loss: 0.2996, Reconstruction Loss: 0.0598, Koopman Loss: 0.1648, Phase Loss: 0.0749
# Epoch: 60, Loss: 0.2910, Reconstruction Loss: 0.0584, Koopman Loss: 0.1593, Phase Loss: 0.0733
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 60, Loss: 0.0714, Reconstruction Loss: 0.0142, Koopman Loss: 0.0393, Phase Loss: 0.0179
# ----------------------------------------------------------------------------------------------------------
# Epoch: 61, Loss: 0.2814, Reconstruction Loss: 0.0562, Koopman Loss: 0.1541, Phase Loss: 0.0711
# Epoch: 62, Loss: 0.2729, Reconstruction Loss: 0.0543, Koopman Loss: 0.1492, Phase Loss: 0.0694
# Epoch: 63, Loss: 0.2647, Reconstruction Loss: 0.0526, Koopman Loss: 0.1445, Phase Loss: 0.0676
# Epoch: 64, Loss: 0.2572, Reconstruction Loss: 0.0513, Koopman Loss: 0.1400, Phase Loss: 0.0660
# Epoch: 65, Loss: 0.2496, Reconstruction Loss: 0.0495, Koopman Loss: 0.1357, Phase Loss: 0.0644
# Epoch: 66, Loss: 0.2420, Reconstruction Loss: 0.0475, Koopman Loss: 0.1316, Phase Loss: 0.0628
# Epoch: 67, Loss: 0.2353, Reconstruction Loss: 0.0461, Koopman Loss: 0.1277, Phase Loss: 0.0614
# Epoch: 68, Loss: 0.2305, Reconstruction Loss: 0.0460, Koopman Loss: 0.1240, Phase Loss: 0.0605
# Epoch: 69, Loss: 0.2235, Reconstruction Loss: 0.0440, Koopman Loss: 0.1205, Phase Loss: 0.0589
# Epoch: 70, Loss: 0.2179, Reconstruction Loss: 0.0430, Koopman Loss: 0.1172, Phase Loss: 0.0577
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 70, Loss: 0.0534, Reconstruction Loss: 0.0102, Koopman Loss: 0.0290, Phase Loss: 0.0141
# ----------------------------------------------------------------------------------------------------------
# Epoch: 71, Loss: 0.2118, Reconstruction Loss: 0.0412, Koopman Loss: 0.1141, Phase Loss: 0.0565
# Epoch: 72, Loss: 0.2071, Reconstruction Loss: 0.0405, Koopman Loss: 0.1111, Phase Loss: 0.0555
# Epoch: 73, Loss: 0.2014, Reconstruction Loss: 0.0390, Koopman Loss: 0.1082, Phase Loss: 0.0542
# Epoch: 74, Loss: 0.1972, Reconstruction Loss: 0.0384, Koopman Loss: 0.1054, Phase Loss: 0.0533
# Epoch: 75, Loss: 0.1928, Reconstruction Loss: 0.0377, Koopman Loss: 0.1028, Phase Loss: 0.0523
# Epoch: 76, Loss: 0.1874, Reconstruction Loss: 0.0360, Koopman Loss: 0.1003, Phase Loss: 0.0511
# Epoch: 77, Loss: 0.1837, Reconstruction Loss: 0.0355, Koopman Loss: 0.0979, Phase Loss: 0.0503
# Epoch: 78, Loss: 0.1796, Reconstruction Loss: 0.0347, Koopman Loss: 0.0956, Phase Loss: 0.0493
# Epoch: 79, Loss: 0.1743, Reconstruction Loss: 0.0329, Koopman Loss: 0.0934, Phase Loss: 0.0481
# Epoch: 80, Loss: 0.1722, Reconstruction Loss: 0.0335, Koopman Loss: 0.0912, Phase Loss: 0.0476
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 80, Loss: 0.0420, Reconstruction Loss: 0.0078, Koopman Loss: 0.0226, Phase Loss: 0.0116
# ----------------------------------------------------------------------------------------------------------
# Epoch: 81, Loss: 0.1674, Reconstruction Loss: 0.0318, Koopman Loss: 0.0891, Phase Loss: 0.0465
# Epoch: 82, Loss: 0.1642, Reconstruction Loss: 0.0313, Koopman Loss: 0.0871, Phase Loss: 0.0458
# Epoch: 83, Loss: 0.1610, Reconstruction Loss: 0.0308, Koopman Loss: 0.0852, Phase Loss: 0.0450
# Epoch: 84, Loss: 0.1585, Reconstruction Loss: 0.0307, Koopman Loss: 0.0833, Phase Loss: 0.0444
# Epoch: 85, Loss: 0.1538, Reconstruction Loss: 0.0289, Koopman Loss: 0.0816, Phase Loss: 0.0433
# Epoch: 86, Loss: 0.1515, Reconstruction Loss: 0.0289, Koopman Loss: 0.0798, Phase Loss: 0.0427
# Epoch: 87, Loss: 0.1489, Reconstruction Loss: 0.0285, Koopman Loss: 0.0782, Phase Loss: 0.0421
# Epoch: 88, Loss: 0.1467, Reconstruction Loss: 0.0283, Koopman Loss: 0.0767, Phase Loss: 0.0417
# Epoch: 89, Loss: 0.1426, Reconstruction Loss: 0.0269, Koopman Loss: 0.0752, Phase Loss: 0.0405
# Epoch: 90, Loss: 0.1408, Reconstruction Loss: 0.0270, Koopman Loss: 0.0737, Phase Loss: 0.0401
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 90, Loss: 0.0345, Reconstruction Loss: 0.0064, Koopman Loss: 0.0183, Phase Loss: 0.0099
# ----------------------------------------------------------------------------------------------------------
# Epoch: 91, Loss: 0.1375, Reconstruction Loss: 0.0259, Koopman Loss: 0.0723, Phase Loss: 0.0393
# Epoch: 92, Loss: 0.1361, Reconstruction Loss: 0.0262, Koopman Loss: 0.0709, Phase Loss: 0.0389
# Epoch: 93, Loss: 0.1328, Reconstruction Loss: 0.0251, Koopman Loss: 0.0696, Phase Loss: 0.0381
# Epoch: 94, Loss: 0.1309, Reconstruction Loss: 0.0248, Koopman Loss: 0.0684, Phase Loss: 0.0377
# Epoch: 95, Loss: 0.1286, Reconstruction Loss: 0.0245, Koopman Loss: 0.0671, Phase Loss: 0.0370
# Epoch: 96, Loss: 0.1282, Reconstruction Loss: 0.0254, Koopman Loss: 0.0660, Phase Loss: 0.0368
# Epoch: 97, Loss: 0.1237, Reconstruction Loss: 0.0231, Koopman Loss: 0.0648, Phase Loss: 0.0357
# Epoch: 98, Loss: 0.1229, Reconstruction Loss: 0.0236, Koopman Loss: 0.0637, Phase Loss: 0.0356
# Epoch: 99, Loss: 0.1206, Reconstruction Loss: 0.0231, Koopman Loss: 0.0626, Phase Loss: 0.0349

# %% [markdown]
# #### Explain the loss dynamics and justify your design choices
# The loss contains the three terms listed above : reconstruction error, prediction error in the Koopman space, prediction error in the phase space that each have the same multiplicative factor. The weights of the encoder have been freezed as suggested.
# During the 100 epochs of training, the loss on the validation set greatly shrinks (from 101.39 to 0.03). On the train set, the loss is decreasing very slowly on the last 10 epochs. As 100 epochs already took roughly 12 minutes to run on a CPU, we do not train the model any more.

# %% [markdown]
# #### Verification

# %% [markdown]
# **Question 4.** : We want to ensure the Koopman operator is stable. This can be verified by checking whether its spectral radius $\rho(\mathbf{K})\le 1$. Plot the eigenvalues of the Koopman operator in order to verify the bound on its spectral radius. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
# TODO: Check Koopman stability and plot the eigen values of the Koopman operator against the unit circle

koopman_matrix = koopman_operator.koopman_matrix

eigenvalues = np.linalg.eigvals(koopman_matrix)

fig, ax = plt.subplots()
ax.scatter(np.real(eigenvalues), np.imag(eigenvalues))
ax.set_aspect('equal')
ax.add_patch(plt.Circle((0, 0), 1, color='r', fill=False))
ax.set_xlabel('Real')
ax.set_ylabel('Imaginary')
ax.set_title('Eigenvalues of Koopman Operator')
plt.show()

# %% [markdown]
# The eigenvalues remain in the unit circle so the Koopman operator is stable

# %%
n_grid = 30
x1_min, x1_max = -2, 2
x2_min, x2_max = -2, 2

array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

array3d_dynamics = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        array3d_dynamics[i, j, :] = duffing(np.array([x1, x2]))

# Set evaluation mode
autoencoder.eval()
koopman_operator.eval()

array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
        tensor2d_observable = autoencoder.encoder(tensor2d_x)
        tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)
        array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

        # Here we compute a discretised version of the derivative thanks to the Koopman operator
        # and the learned encoder/decoder

        # (x_{k+1} - x_k) / \delta_t = f(x_k) is approximated by (f is duffing here)
        # (Decod(K(Encod(x_k))) - x_k) / \delta_t

        delta_time = (t_max / n_iter)
        array3d_dynamics_pred[i, j, :] = (array_x_next - [x1, x2]) / delta_time

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131)
ax.quiver(matrix_grid_x1,
          matrix_grid_x2,
          array3d_dynamics[:, :, 0],
          array3d_dynamics[:, :, 1], scale=10)
ax.set_title('True')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(132)
ax.quiver(matrix_grid_x1,
          matrix_grid_x2,
          array3d_dynamics_pred[:, :, 0],
          array3d_dynamics_pred[:, :, 1], scale=10)

ax.set_title('Prediction')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

# Compute the error
matrix_error = np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)
matrix_error_log = np.log10(matrix_error + 1e-10)

ax = fig.add_subplot(133)
cp = ax.contourf(matrix_grid_x1,
                 matrix_grid_x2,
                 matrix_error_log)

fig.colorbar(cp)
ax.set_title('Error in log scale')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()

# %% [markdown]
# ### Continuous in time case
#
# Considering $x_k$ as the observation of a state at time $t = k \delta$, and $x_{k+1}$ the state at time $t+ \delta$, for $\delta \rightarrow 0$  it is also possible to define the continuous-time infinitesimal generator of the Koopman operator family as
#
# $$
# \mathcal{L} g (x_k)  = \lim_{\delta \rightarrow 0} \frac{\mathcal{K}g(x_k)- g(x_{k})}{\delta} = \frac{g \circ F (x_k) -x_k}{\delta}
# $$
#
# The pevious expression defines the Lie derivative, and for this reason $\mathcal{L}$ is known as the Lie operator. $\mathcal{L}$ describes the continuous dynamics of the observables in the Koopman space:
#
# $$
# \dot{g} (x) = \mathcal{L} g(x).
# $$
#
# The latter can be further expressed as:
#
# $$
# \dot{g} (x(t)) = \frac{dg(x)}{dt} = \nabla_x g \frac{dx}{dt} = \nabla_x g \cdot f(x) =\mathcal{L} g(x).
# $$
#
# Given $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{L}_{\phi}$ three parameterized functions, the following conditions hold:
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x)) - x  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{L_{\phi}} g_{\theta} ( x ) - \nabla g_{\theta} \cdot f(x)  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{L_{\phi}} g_{\theta} ( x )\right) - f(x) \Vert = 0
#      $$
#
# **Important Remark: As long as the system $f$ is known, the three errors can be computed without data belonging to trajectories.**

# %%
# Create a dataset for continuous Koopman
# with the same amount of points of the Discontinuous Koopman case
# But here no need to have continuous trajectories
matrix_x0 = (np.random.rand(n_initial_conditions * (n_iter - 1), 2) - 0.5) * 4
matrix_system_derivative_data = np.zeros(matrix_x0.shape)
for i in tqdm(range(matrix_x0.shape[0])):
    matrix_system_derivative_data[i, :] = duffing(matrix_x0[i, :])
# Out:
#  14%|█▎        | 40645/299940 [00:00<00:01, 202565.12it/s]
# 100%|██████████| 299940/299940 [00:01<00:00, 223549.18it/s]

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.quiver(matrix_x0[::50, 0],
          matrix_x0[::50, 1],
          matrix_system_derivative_data[::50, 0] * 0.2,
          matrix_system_derivative_data[::50, 1] * 0.2, scale=10)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()

# %%
# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER) 
output_dim = 30  # dimension in Koopman space
batch_size = 2000  # data per batch

# %%
(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x0,
                                             matrix_system_derivative_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)

torch_dataset_train = TensorDataset(torch.from_numpy(matrix_x_data_train),
                                    torch.from_numpy(matrix_x_next_data_train))
torch_dataset_test = TensorDataset(torch.from_numpy(matrix_x_data_test),
                                   torch.from_numpy(matrix_x_next_data_test))

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim, hidden_layer, output_dim):
        super().__init__()

        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]

        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.encoder(tensor2d_x)
        return self.decoder(tensor2d_x)

# %% [markdown]
# The Lie operator must be defined such that it will be always stable by construction.
# To do that, we consider a matrix of parameters $\Psi \in \mathbb{R}^{m \times m}$ and a vector of parameters $\Gamma \in \mathbb{R}^m$. The resulting Lie operator will be of the form:
#
# $$
# \mathbf{L} = (\Psi - \Psi^T) - \text{diag}(\vert \Gamma \vert)
# $$
#
# with eigenvalues whose real part $\Re(\lambda) \leq 0$ .
# See https://math.stackexchange.com/questions/952233/eigenvalues-of-the-sum-of-a-diagonal-matrix-and-a-skew-symmetric-matrix for the mathematical proof (identify the matrix). Moreover if $\lambda \in \mathbb{C}$ is an eigenvalue of $\mathbf{L}$, it turns out that its real part $\Re(\lambda) \propto \Vert \Gamma \Vert$, i.e. it only depends on $\Gamma$.
#
# Remark: $- \text{diag}(\vert \Gamma \vert)$ is always a diagonal matrix with non-positive elements.

# %% [markdown]
# **Question 4.** : As you did for the discrete case, you now have to implement the `LieModule` module. It should have the form indicated above to guarantee $\Re(\lambda) \leq 0$. Check that the initialization fulfills this property.

# %%
class LieModule(nn.Module):
    def __init__(self, lie_operator_dim: int):
        super().__init__()
        self.lie_operator_dim = lie_operator_dim
        self.weight = torch.nn.Parameter(torch.randn(lie_operator_dim, lie_operator_dim))        
        self.diag = torch.nn.Parameter(torch.randn(lie_operator_dim))
        
    def forward(self, tensor2d_x: torch.Tensor):
        return torch.matmul(tensor2d_x, self.L().t())
    
    def L(self):
        return self.weight - self.weight.t() - torch.diag(torch.abs(self.diag))

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
lie_operator = LieModule(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %%
# TODO: Check the eigenvalues real part of the initialisation

eigenvalues_lie = np.linalg.eigvals(lie_operator.L().detach().numpy())
real_sorted = np.sort(np.real(eigenvalues_lie))
print(real_sorted)
print(f"{sum(real_sorted > 0)} positives eigenvalues out of {len(real_sorted)}")
# Out:
# [-1.0146013  -1.0146013  -0.9304433  -0.9304433  -0.8850757  -0.8850757
#  -0.8567436  -0.8567436  -0.8516011  -0.8516011  -0.8412568  -0.8412568
#  -0.8407638  -0.8407638  -0.8124457  -0.8124457  -0.80496126 -0.80496126
#  -0.7803348  -0.7803348  -0.7771715  -0.7771715  -0.7497471  -0.7497471
#  -0.7386924  -0.7386924  -0.72917473 -0.72917473 -0.68513167 -0.68513167]
# 0 positives eigenvalues out of 30

# %% [markdown]
# Some tricks are needed to train. If the autoencoder and the Lie model are learned at the same speed, the training turns out to be highly unstable since the three loss functions have moving targets. For this reason, the Lie learning rate has been chosen smaller than the autoencoder one.

# %%
learning_rate_autoencoder = 0.0001
learning_rate_lie = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder,
                                         weight_decay=1e-3)
optimiser_lie = torch.optim.Adam(lie_operator.parameters(),
                                 lr=learning_rate_lie,
                                 weight_decay=1e-3)

# %% [markdown]
# A further loss is considered to stabilize the learning stage. The state $x$ belongs to a compact set, since it is the solution of a dissipative dynamical system. This is not true for $g(x)$ (we need to choose appropriate activation functions to have appropriate Liptchitz guarantees). To avoid discrepancies in magnitudes of $g_i(x)$, a regularization loss is added:
#
# $$
# \mu = \frac{1}{m} \sum_m g_i(x) = 0  \quad \text{and} \quad  \sigma = \left( \frac{1}{m}\sum_m(g_i(x)-\mu)^2 \right)^{1/2} = 1
# $$
#
# inspired by VAE.
#
# For the training to be smooth, the encoder parameters are not affected by the **prediction loss in phase space**. This is based on an empirical observation and is motivated by the fact that the encoder appears in the three losses and plays a competitive role against the decoder and the Lie model. This should not affect the results since the encoder remains coupled with the decoder in the **reconstruction loss** and with the Lie operator in the **prediction loss in Koopman space**.

# %% [markdown]
# **Question 5.** : Implement the loss function similarly to what you did for the **Question 2.** Note that here you should use the dynamics $f$ and its values for a set of points belonging to the domain $\left[ -2, 2 \right]^2$ while no data from proper **trajectories** are needed.

# %%
# Implement the loss function here
# See the training process below to identify the different components of the loss
def loss(tensor2d_x: torch.Tensor, #
         tensor2d_x_next: torch.Tensor, #
         tensor2d_decoded_x: torch.Tensor, #
         tensor2d_observable_next: torch.Tensor,
         tensor2d_lie_observable_next: torch.Tensor,
         tensor2d_predict_x_next: torch.Tensor, #
         tensor2d_jvp: torch.Tensor):

    criterion = nn.MSELoss()
    coef = [1, 10, 1, 1]

    # Freeze encoder
    for p in autoencoder.encoder.parameters():
        p.requires_grad = False

    reconstruction_loss = criterion(tensor2d_decoded_x, tensor2d_x)
    lie_loss = criterion(tensor2d_lie_observable_next, tensor2d_jvp)
    phase_loss = criterion(tensor2d_predict_x_next, tensor2d_x_next)
    vaelike_loss = torch.abs(torch.mean(tensor2d_observable_next)) + torch.abs(torch.std(tensor2d_observable_next)-1)


    # Restore the gradient computation
    for p in autoencoder.encoder.parameters():
        p.requires_grad = True

    # Total loss
    total_loss = coef[0]*reconstruction_loss + coef[1]*lie_loss + coef[2]*phase_loss + coef[3]*vaelike_loss

    return total_loss, reconstruction_loss, lie_loss, phase_loss, vaelike_loss

# %% [markdown]
# **Since trajectories are not needed**, random states can be sampled from the system manifold $x_1 \in [-2, 2]$, $x_2 \in [-2, 2]$.

# %%
n_batch = len(train_dataloader)
n_epoch = 100  # To be tuned 

for epoch in range(n_epoch):
    autoencoder.train()
    lie_operator.train()
    total_train_loss = 0
    total_loss1, total_loss2, total_loss3, total_loss4 = 0, 0, 0, 0
    for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
        tensor2d_batch_x = tensor2d_batch_x.to(device)
        tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

        optimiser_autoencoder.zero_grad()
        optimiser_lie.zero_grad()

        # dgX = lie_operator * gX
        # jvp = \nabla_x g (x) * f(x) (jvp: jacobian vector product)
        (tensor2d_observable, tensor2d_jvp) = \
            autograd.functional.jvp(autoencoder.encoder,
                                    tensor2d_batch_x,
                                    tensor2d_batch_x_next,
                                    create_graph=True)

        tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)

        tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)

        tensor_loss_val, tensor_loss1, tensor_loss2, tensor_loss3, tensor_loss4 = \
            loss(tensor2d_x=tensor2d_batch_x,
                 tensor2d_x_next=tensor2d_batch_x_next,
                 tensor2d_decoded_x=tensor2d_decoded_x,
                 tensor2d_observable_next=tensor2d_observable,
                 tensor2d_lie_observable_next=tensor2d_lie_observable_next,
                 tensor2d_predict_x_next=tensor2d_predict_x_next,
                 tensor2d_jvp=tensor2d_jvp)

        tensor_loss_val.backward()
        optimiser_autoencoder.step()
        optimiser_lie.step()

        if epoch % 1 == 0:
            total_train_loss += tensor_loss_val.item()
            total_loss1 += tensor_loss1.item()
            total_loss2 += tensor_loss2.item()
            total_loss3 += tensor_loss3.item()
            total_loss4 += tensor_loss4.item()

    if epoch % 1 == 0:
        print(
            f'Epoch: {epoch}, Loss: {total_train_loss:.4f}, '
            f'Reconstruction Loss: {total_loss1:.4f}, '
            f'Lie Loss: {total_loss2:.4f}, '
            f'Phase Loss: {total_loss3:.4f}, '
            f'Vaelike Loss: {total_loss4:.4f}'
        )

    if epoch % 10 == 0:
        autoencoder.eval()
        lie_operator.eval()
        with torch.no_grad():
            total_test_loss = 0
            total_test_loss1, total_test_loss2, total_test_loss3, total_test_loss4 = 0, 0, 0, 0
            for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                tensor2d_batch_x = tensor2d_batch_x.to(device)
                tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                (tensor2d_observable, tensor2d_jvp) = \
                    autograd.functional.jvp(autoencoder.encoder,
                                            tensor2d_batch_x,
                                            tensor2d_batch_x_next,
                                            create_graph=True)
                tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)

                tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
                tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)

                tensor_loss_val, tensor_loss1, tensor_loss2, tensor_loss3, tensor_loss4 = \
                    loss(tensor2d_x=tensor2d_batch_x,
                         tensor2d_x_next=tensor2d_batch_x_next,
                         tensor2d_decoded_x=tensor2d_decoded_x,
                         tensor2d_observable_next=tensor2d_observable,
                         tensor2d_lie_observable_next=tensor2d_lie_observable_next,
                         tensor2d_predict_x_next=tensor2d_predict_x_next,
                         tensor2d_jvp=tensor2d_jvp)

                total_test_loss += tensor_loss_val.item()
                total_test_loss1 += tensor_loss1.item()
                total_test_loss2 += tensor_loss2.item()
                total_test_loss3 += tensor_loss3.item()
                total_test_loss4 += tensor_loss4.item()

            print('-' * 50, 'TEST', '-' * 50)
            print(
                f'Epoch: {epoch}, Loss: {total_test_loss:.4f}, '
                f'Reconstruction Loss: {total_test_loss1:.4f}, '
                f'Lie Loss: {total_test_loss2:.4f}, '
                f'Phase Loss: {total_test_loss3:.4f}, '
                f'Vaelike Loss: {total_test_loss4:.4f}'
            )
            print('-' * 106)
# Out:
# Epoch: 0, Loss: 1151.0969, Reconstruction Loss: 169.0878, Lie Loss: 54.8704, Phase Loss: 327.7570, Vaelike Loss: 105.5485
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 0, Loss: 213.3490, Reconstruction Loss: 41.7248, Lie Loss: 6.4590, Phase Loss: 80.2123, Vaelike Loss: 26.8219
# ----------------------------------------------------------------------------------------------------------
# Epoch: 1, Loss: 748.5643, Reconstruction Loss: 164.1671, Lie Loss: 16.1116, Phase Loss: 314.6894, Vaelike Loss: 108.5916
# Epoch: 2, Loss: 624.8672, Reconstruction Loss: 159.6587, Lie Loss: 6.6471, Phase Loss: 288.3377, Vaelike Loss: 110.4003
# Epoch: 3, Loss: 547.8144, Reconstruction Loss: 154.2468, Lie Loss: 3.9698, Phase Loss: 242.4020, Vaelike Loss: 111.4679
# Epoch: 4, Loss: 494.1939, Reconstruction Loss: 139.7819, Lie Loss: 2.9862, Phase Loss: 212.4048, Vaelike Loss: 112.1452
# Epoch: 5, Loss: 453.5580, Reconstruction Loss: 115.0248, Lie Loss: 2.4842, Phase Loss: 201.1752, Vaelike Loss: 112.5157
# Epoch: 6, Loss: 419.7089, Reconstruction Loss: 93.5819, Lie Loss: 2.2076, Phase Loss: 191.4135, Vaelike Loss: 112.6377
# Epoch: 7, Loss: 392.9270, Reconstruction Loss: 83.5836, Lie Loss: 1.8909, Phase Loss: 177.7591, Vaelike Loss: 112.6755
# Epoch: 8, Loss: 365.3523, Reconstruction Loss: 79.6712, Lie Loss: 1.7017, Phase Loss: 155.9570, Vaelike Loss: 112.7067
# Epoch: 9, Loss: 327.8120, Reconstruction Loss: 75.7134, Lie Loss: 1.6318, Phase Loss: 123.0481, Vaelike Loss: 112.7322
# Epoch: 10, Loss: 280.2919, Reconstruction Loss: 67.4188, Lie Loss: 1.5293, Phase Loss: 84.8510, Vaelike Loss: 112.7291
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 10, Loss: 63.6190, Reconstruction Loss: 15.1471, Lie Loss: 0.3737, Phase Loss: 16.5611, Vaelike Loss: 28.1734
# ----------------------------------------------------------------------------------------------------------
# Epoch: 11, Loss: 230.3563, Reconstruction Loss: 50.9273, Lie Loss: 1.5385, Phase Loss: 51.4325, Vaelike Loss: 112.6120
# Epoch: 12, Loss: 193.3340, Reconstruction Loss: 30.4843, Lie Loss: 1.6979, Phase Loss: 33.4810, Vaelike Loss: 112.3897
# Epoch: 13, Loss: 173.6619, Reconstruction Loss: 17.2990, Lie Loss: 1.7027, Phase Loss: 27.1138, Vaelike Loss: 112.2216
# Epoch: 14, Loss: 162.9515, Reconstruction Loss: 11.3068, Lie Loss: 1.5534, Phase Loss: 23.9797, Vaelike Loss: 112.1314
# Epoch: 15, Loss: 155.6993, Reconstruction Loss: 8.2351, Lie Loss: 1.3875, Phase Loss: 21.5234, Vaelike Loss: 112.0661
# Epoch: 16, Loss: 150.3332, Reconstruction Loss: 6.3635, Lie Loss: 1.2425, Phase Loss: 19.5463, Vaelike Loss: 111.9989
# Epoch: 17, Loss: 146.0352, Reconstruction Loss: 5.1109, Lie Loss: 1.1216, Phase Loss: 17.7786, Vaelike Loss: 111.9295
# Epoch: 18, Loss: 142.5547, Reconstruction Loss: 4.2242, Lie Loss: 1.0206, Phase Loss: 16.2713, Vaelike Loss: 111.8534
# Epoch: 19, Loss: 139.5471, Reconstruction Loss: 3.5778, Lie Loss: 0.9365, Phase Loss: 14.8326, Vaelike Loss: 111.7717
# Epoch: 20, Loss: 136.9504, Reconstruction Loss: 3.0756, Lie Loss: 0.8661, Phase Loss: 13.5260, Vaelike Loss: 111.6882
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 20, Loss: 33.9457, Reconstruction Loss: 0.7131, Lie Loss: 0.2093, Phase Loss: 3.2296, Vaelike Loss: 27.9101
# ----------------------------------------------------------------------------------------------------------
# Epoch: 21, Loss: 134.6440, Reconstruction Loss: 2.6649, Lie Loss: 0.8075, Phase Loss: 12.3083, Vaelike Loss: 111.5959
# Epoch: 22, Loss: 132.6182, Reconstruction Loss: 2.3320, Lie Loss: 0.7581, Phase Loss: 11.2084, Vaelike Loss: 111.4971
# Epoch: 23, Loss: 130.8663, Reconstruction Loss: 2.0476, Lie Loss: 0.7169, Phase Loss: 10.2524, Vaelike Loss: 111.3970
# Epoch: 24, Loss: 129.2233, Reconstruction Loss: 1.8110, Lie Loss: 0.6823, Phase Loss: 9.2898, Vaelike Loss: 111.2995
# Epoch: 25, Loss: 127.7958, Reconstruction Loss: 1.6074, Lie Loss: 0.6532, Phase Loss: 8.4535, Vaelike Loss: 111.2031
# Epoch: 26, Loss: 126.4411, Reconstruction Loss: 1.4380, Lie Loss: 0.6283, Phase Loss: 7.6116, Vaelike Loss: 111.1087
# Epoch: 27, Loss: 125.2716, Reconstruction Loss: 1.2884, Lie Loss: 0.6069, Phase Loss: 6.8980, Vaelike Loss: 111.0165
# Epoch: 28, Loss: 124.1371, Reconstruction Loss: 1.1568, Lie Loss: 0.5881, Phase Loss: 6.1786, Vaelike Loss: 110.9209
# Epoch: 29, Loss: 123.2043, Reconstruction Loss: 1.0417, Lie Loss: 0.5718, Phase Loss: 5.6228, Vaelike Loss: 110.8216
# Epoch: 30, Loss: 122.3131, Reconstruction Loss: 0.9365, Lie Loss: 0.5577, Phase Loss: 5.0774, Vaelike Loss: 110.7221
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 30, Loss: 30.4478, Reconstruction Loss: 0.2213, Lie Loss: 0.1381, Phase Loss: 1.1787, Vaelike Loss: 27.6672
# ----------------------------------------------------------------------------------------------------------
# Epoch: 31, Loss: 121.4646, Reconstruction Loss: 0.8427, Lie Loss: 0.5457, Phase Loss: 4.5461, Vaelike Loss: 110.6187
# Epoch: 32, Loss: 120.7594, Reconstruction Loss: 0.7600, Lie Loss: 0.5351, Phase Loss: 4.1300, Vaelike Loss: 110.5187
# Epoch: 33, Loss: 120.0570, Reconstruction Loss: 0.6847, Lie Loss: 0.5260, Phase Loss: 3.6944, Vaelike Loss: 110.4179
# Epoch: 34, Loss: 119.5324, Reconstruction Loss: 0.6188, Lie Loss: 0.5181, Phase Loss: 3.4148, Vaelike Loss: 110.3176
# Epoch: 35, Loss: 118.9359, Reconstruction Loss: 0.5595, Lie Loss: 0.5113, Phase Loss: 3.0417, Vaelike Loss: 110.2217
# Epoch: 36, Loss: 118.4317, Reconstruction Loss: 0.5068, Lie Loss: 0.5055, Phase Loss: 2.7450, Vaelike Loss: 110.1253
# Epoch: 37, Loss: 118.0223, Reconstruction Loss: 0.4595, Lie Loss: 0.5003, Phase Loss: 2.5309, Vaelike Loss: 110.0287
# Epoch: 38, Loss: 117.5791, Reconstruction Loss: 0.4173, Lie Loss: 0.4960, Phase Loss: 2.2684, Vaelike Loss: 109.9333
# Epoch: 39, Loss: 117.2189, Reconstruction Loss: 0.3794, Lie Loss: 0.4922, Phase Loss: 2.0782, Vaelike Loss: 109.8392
# Epoch: 40, Loss: 117.0096, Reconstruction Loss: 0.3466, Lie Loss: 0.4891, Phase Loss: 2.0286, Vaelike Loss: 109.7432
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 40, Loss: 29.1844, Reconstruction Loss: 0.0830, Lie Loss: 0.1222, Phase Loss: 0.4558, Vaelike Loss: 27.4235
# ----------------------------------------------------------------------------------------------------------
# Epoch: 41, Loss: 116.5350, Reconstruction Loss: 0.3172, Lie Loss: 0.4865, Phase Loss: 1.6991, Vaelike Loss: 109.6532
# Epoch: 42, Loss: 116.3123, Reconstruction Loss: 0.2907, Lie Loss: 0.4841, Phase Loss: 1.6170, Vaelike Loss: 109.5633
# Epoch: 43, Loss: 116.0697, Reconstruction Loss: 0.2679, Lie Loss: 0.4823, Phase Loss: 1.5056, Vaelike Loss: 109.4729
# Epoch: 44, Loss: 115.8979, Reconstruction Loss: 0.2472, Lie Loss: 0.4807, Phase Loss: 1.4582, Vaelike Loss: 109.3850
# Epoch: 45, Loss: 115.6187, Reconstruction Loss: 0.2290, Lie Loss: 0.4796, Phase Loss: 1.2963, Vaelike Loss: 109.2978
# Epoch: 46, Loss: 115.4693, Reconstruction Loss: 0.2127, Lie Loss: 0.4785, Phase Loss: 1.2584, Vaelike Loss: 109.2130
# Epoch: 47, Loss: 115.2011, Reconstruction Loss: 0.1981, Lie Loss: 0.4776, Phase Loss: 1.0968, Vaelike Loss: 109.1299
# Epoch: 48, Loss: 115.0191, Reconstruction Loss: 0.1847, Lie Loss: 0.4772, Phase Loss: 1.0189, Vaelike Loss: 109.0437
# Epoch: 49, Loss: 114.9462, Reconstruction Loss: 0.1732, Lie Loss: 0.4768, Phase Loss: 1.0470, Vaelike Loss: 108.9575
# Epoch: 50, Loss: 114.7731, Reconstruction Loss: 0.1626, Lie Loss: 0.4769, Phase Loss: 0.9699, Vaelike Loss: 108.8716
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 50, Loss: 28.6622, Reconstruction Loss: 0.0395, Lie Loss: 0.1194, Phase Loss: 0.2213, Vaelike Loss: 27.2077
# ----------------------------------------------------------------------------------------------------------
# Epoch: 51, Loss: 114.5901, Reconstruction Loss: 0.1530, Lie Loss: 0.4769, Phase Loss: 0.8779, Vaelike Loss: 108.7903
# Epoch: 52, Loss: 114.4365, Reconstruction Loss: 0.1446, Lie Loss: 0.4772, Phase Loss: 0.8149, Vaelike Loss: 108.7050
# Epoch: 53, Loss: 114.4183, Reconstruction Loss: 0.1370, Lie Loss: 0.4777, Phase Loss: 0.8821, Vaelike Loss: 108.6227
# Epoch: 54, Loss: 114.2424, Reconstruction Loss: 0.1301, Lie Loss: 0.4782, Phase Loss: 0.7897, Vaelike Loss: 108.5404
# Epoch: 55, Loss: 114.1797, Reconstruction Loss: 0.1239, Lie Loss: 0.4789, Phase Loss: 0.8069, Vaelike Loss: 108.4598
# Epoch: 56, Loss: 113.9784, Reconstruction Loss: 0.1180, Lie Loss: 0.4797, Phase Loss: 0.6841, Vaelike Loss: 108.3794
# Epoch: 57, Loss: 113.9402, Reconstruction Loss: 0.1129, Lie Loss: 0.4806, Phase Loss: 0.7229, Vaelike Loss: 108.2984
# Epoch: 58, Loss: 113.8666, Reconstruction Loss: 0.1083, Lie Loss: 0.4816, Phase Loss: 0.7235, Vaelike Loss: 108.2186
# Epoch: 59, Loss: 113.6568, Reconstruction Loss: 0.1036, Lie Loss: 0.4827, Phase Loss: 0.5871, Vaelike Loss: 108.1387
# Epoch: 60, Loss: 113.7043, Reconstruction Loss: 0.0999, Lie Loss: 0.4840, Phase Loss: 0.7059, Vaelike Loss: 108.0587
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 60, Loss: 28.6203, Reconstruction Loss: 0.0249, Lie Loss: 0.1214, Phase Loss: 0.3772, Vaelike Loss: 27.0041
# ----------------------------------------------------------------------------------------------------------
# Epoch: 61, Loss: 113.5225, Reconstruction Loss: 0.0960, Lie Loss: 0.4852, Phase Loss: 0.5931, Vaelike Loss: 107.9816
# Epoch: 62, Loss: 113.4679, Reconstruction Loss: 0.0925, Lie Loss: 0.4865, Phase Loss: 0.6071, Vaelike Loss: 107.9030
# Epoch: 63, Loss: 113.3926, Reconstruction Loss: 0.0894, Lie Loss: 0.4880, Phase Loss: 0.5994, Vaelike Loss: 107.8241
# Epoch: 64, Loss: 113.3119, Reconstruction Loss: 0.0864, Lie Loss: 0.4895, Phase Loss: 0.5853, Vaelike Loss: 107.7452
# Epoch: 65, Loss: 113.2607, Reconstruction Loss: 0.0836, Lie Loss: 0.4911, Phase Loss: 0.5990, Vaelike Loss: 107.6668
# Epoch: 66, Loss: 113.1461, Reconstruction Loss: 0.0810, Lie Loss: 0.4928, Phase Loss: 0.5479, Vaelike Loss: 107.5890
# Epoch: 67, Loss: 113.0745, Reconstruction Loss: 0.0785, Lie Loss: 0.4945, Phase Loss: 0.5388, Vaelike Loss: 107.5122
# Epoch: 68, Loss: 113.0202, Reconstruction Loss: 0.0762, Lie Loss: 0.4963, Phase Loss: 0.5473, Vaelike Loss: 107.4336
# Epoch: 69, Loss: 112.9725, Reconstruction Loss: 0.0741, Lie Loss: 0.4982, Phase Loss: 0.5615, Vaelike Loss: 107.3553
# Epoch: 70, Loss: 112.8118, Reconstruction Loss: 0.0719, Lie Loss: 0.5001, Phase Loss: 0.4612, Vaelike Loss: 107.2779
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 70, Loss: 28.2183, Reconstruction Loss: 0.0178, Lie Loss: 0.1254, Phase Loss: 0.1361, Vaelike Loss: 26.8104
# ----------------------------------------------------------------------------------------------------------
# Epoch: 71, Loss: 112.8402, Reconstruction Loss: 0.0701, Lie Loss: 0.5020, Phase Loss: 0.5500, Vaelike Loss: 107.1998
# Epoch: 72, Loss: 112.7226, Reconstruction Loss: 0.0682, Lie Loss: 0.5041, Phase Loss: 0.4920, Vaelike Loss: 107.1218
# Epoch: 73, Loss: 112.6936, Reconstruction Loss: 0.0664, Lie Loss: 0.5062, Phase Loss: 0.5213, Vaelike Loss: 107.0439
# Epoch: 74, Loss: 112.5885, Reconstruction Loss: 0.0647, Lie Loss: 0.5084, Phase Loss: 0.4736, Vaelike Loss: 106.9660
# Epoch: 75, Loss: 112.5578, Reconstruction Loss: 0.0633, Lie Loss: 0.5106, Phase Loss: 0.5001, Vaelike Loss: 106.8885
# Epoch: 76, Loss: 112.4787, Reconstruction Loss: 0.0616, Lie Loss: 0.5129, Phase Loss: 0.4777, Vaelike Loss: 106.8106
# Epoch: 77, Loss: 112.4481, Reconstruction Loss: 0.0603, Lie Loss: 0.5151, Phase Loss: 0.5034, Vaelike Loss: 106.7334
# Epoch: 78, Loss: 112.3470, Reconstruction Loss: 0.0590, Lie Loss: 0.5174, Phase Loss: 0.4580, Vaelike Loss: 106.6560
# Epoch: 79, Loss: 112.2855, Reconstruction Loss: 0.0576, Lie Loss: 0.5198, Phase Loss: 0.4520, Vaelike Loss: 106.5779
# Epoch: 80, Loss: 112.2972, Reconstruction Loss: 0.0564, Lie Loss: 0.5222, Phase Loss: 0.5195, Vaelike Loss: 106.4993
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 80, Loss: 28.0490, Reconstruction Loss: 0.0141, Lie Loss: 0.1310, Phase Loss: 0.1094, Vaelike Loss: 26.6154
# ----------------------------------------------------------------------------------------------------------
# Epoch: 81, Loss: 112.1251, Reconstruction Loss: 0.0550, Lie Loss: 0.5246, Phase Loss: 0.4012, Vaelike Loss: 106.4231
# Epoch: 82, Loss: 112.1690, Reconstruction Loss: 0.0540, Lie Loss: 0.5271, Phase Loss: 0.5003, Vaelike Loss: 106.3441
# Epoch: 83, Loss: 112.0229, Reconstruction Loss: 0.0528, Lie Loss: 0.5296, Phase Loss: 0.4077, Vaelike Loss: 106.2665
# Epoch: 84, Loss: 111.9946, Reconstruction Loss: 0.0518, Lie Loss: 0.5321, Phase Loss: 0.4328, Vaelike Loss: 106.1889
# Epoch: 85, Loss: 111.9740, Reconstruction Loss: 0.0507, Lie Loss: 0.5347, Phase Loss: 0.4660, Vaelike Loss: 106.1103
# Epoch: 86, Loss: 111.8655, Reconstruction Loss: 0.0497, Lie Loss: 0.5373, Phase Loss: 0.4112, Vaelike Loss: 106.0313
# Epoch: 87, Loss: 111.8577, Reconstruction Loss: 0.0488, Lie Loss: 0.5400, Phase Loss: 0.4562, Vaelike Loss: 105.9531
# Epoch: 88, Loss: 111.7820, Reconstruction Loss: 0.0479, Lie Loss: 0.5427, Phase Loss: 0.4335, Vaelike Loss: 105.8739
# Epoch: 89, Loss: 111.7119, Reconstruction Loss: 0.0468, Lie Loss: 0.5453, Phase Loss: 0.4150, Vaelike Loss: 105.7973
# Epoch: 90, Loss: 111.7695, Reconstruction Loss: 0.0462, Lie Loss: 0.5480, Phase Loss: 0.5239, Vaelike Loss: 105.7194
# -------------------------------------------------- TEST --------------------------------------------------
# Epoch: 90, Loss: 27.9547, Reconstruction Loss: 0.0113, Lie Loss: 0.1375, Phase Loss: 0.1480, Vaelike Loss: 26.4200
# ----------------------------------------------------------------------------------------------------------
# Epoch: 91, Loss: 111.5437, Reconstruction Loss: 0.0452, Lie Loss: 0.5507, Phase Loss: 0.3501, Vaelike Loss: 105.6415
# Epoch: 92, Loss: 111.5434, Reconstruction Loss: 0.0444, Lie Loss: 0.5534, Phase Loss: 0.4013, Vaelike Loss: 105.5633
# Epoch: 93, Loss: 111.5663, Reconstruction Loss: 0.0437, Lie Loss: 0.5562, Phase Loss: 0.4753, Vaelike Loss: 105.4850
# Epoch: 94, Loss: 111.4211, Reconstruction Loss: 0.0428, Lie Loss: 0.5590, Phase Loss: 0.3811, Vaelike Loss: 105.4074
# Epoch: 95, Loss: 111.4121, Reconstruction Loss: 0.0422, Lie Loss: 0.5618, Phase Loss: 0.4225, Vaelike Loss: 105.3294
# Epoch: 96, Loss: 111.3222, Reconstruction Loss: 0.0414, Lie Loss: 0.5646, Phase Loss: 0.3828, Vaelike Loss: 105.2524
# Epoch: 97, Loss: 111.3111, Reconstruction Loss: 0.0408, Lie Loss: 0.5675, Phase Loss: 0.4225, Vaelike Loss: 105.1731
# Epoch: 98, Loss: 111.2436, Reconstruction Loss: 0.0402, Lie Loss: 0.5703, Phase Loss: 0.4049, Vaelike Loss: 105.0953
# Epoch: 99, Loss: 111.1643, Reconstruction Loss: 0.0394, Lie Loss: 0.5732, Phase Loss: 0.3772, Vaelike Loss: 105.0152

# %% [markdown]
# #### Explain the loss dynamics and justify your design choices
# The loss contains the three terms listed above : reconstruction error, prediction error in the Koopman space, prediction error in the phase space that each have the same multiplicative factor. In addition to that, we added the VAE-like loss with a 10 times greater multiplicative factor. The weights of the encoder have been freezed as suggested.
# During the 100 epochs of training, the loss on the validation set greatly shrinks (from 213 to 28.0). On the train set, the loss is decreasing very slowly on the last 20 epochs.

# %% [markdown]
# ### Verification

# %% [markdown]
# **Question 6.** : As in the **Question 3.** we want to ensure the Lie operator is stable. This can be verified by checking that the real part of the eigenvalues is negative. Plot the relevant eigenvalues of the Lie operator. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
# TODO: Check the eigenvalues real part

eigenvalues_lie = np.linalg.eigvals(lie_operator.L().detach().numpy())
real_sorted = np.sort(np.real(eigenvalues_lie))
print(real_sorted)
print(f"{sum(real_sorted > 0)} positives eigenvalues out of {len(real_sorted)}")
# Out:
# [-0.96640676 -0.96640676 -0.9195713  -0.89652455 -0.89652455 -0.84242904
#  -0.84242904 -0.81621474 -0.81621474 -0.81388927 -0.81388927 -0.8099818
#  -0.8099818  -0.79861385 -0.79861385 -0.774324   -0.774324   -0.76002586
#  -0.76002586 -0.74445057 -0.74445057 -0.7335783  -0.7335783  -0.70923835
#  -0.70923835 -0.70714426 -0.70714426 -0.661069   -0.661069   -0.5321108 ]
# 0 positives eigenvalues out of 30

# %%
# TODO: Plot the eigenvalues

fig, ax = plt.subplots()
ax.scatter(np.real(eigenvalues_lie), np.imag(eigenvalues_lie))
ax.axvline(x=0, color='red', linestyle='--')
ax.set_xlabel('Real')
ax.set_ylabel('Imaginary')
ax.set_title('Eigenvalues of Lie Operator')
plt.show()

# %%
n_grid = 30
array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

array3d_dynamics = np.zeros((n_grid, n_grid, 2))

for i in range(n_grid):
    for j in range(n_grid):
        array3d_dynamics[i, j, :] = duffing(np.array([matrix_grid_x1[i, j], matrix_grid_x2[i, j]]))

autoencoder.eval()
lie_operator.eval()
array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2))
for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
        tensor2d_observable = autoencoder.encoder(tensor2d_x)
        tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)
        array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

        array3d_dynamics_pred[i, j, :] = array_x_next

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics[:, :, 0], array3d_dynamics[:, :, 1], scale=10)
ax.set_title('True')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(132)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics_pred[:, :, 0], array3d_dynamics_pred[:, :, 1], scale=10)
ax.set_title('Prediction')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(133)
cp = ax.contourf(matrix_grid_x1, matrix_grid_x2,
                 np.log(np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)))
fig.colorbar(cp)
ax.set_title('Error in log scale')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

plt.show()

# %% [markdown]
# **Question 7.** : Compare and comment below the two approaches (discrete vs continuous operator).

# %% [markdown]
# On top (discrete operator) and on botom (continuous operator).
#
# Both reconstructions are okay by comparing the "True" vector field to the predicted one. We observe that the error is smaller overall when using the continuous operator, and more homogeneous. Besides, computationnaly speaking, the continuous model is more efficient.

# %% [markdown]
# ![discrete](./discrete.png)
# ![continuous](./continuous.png)

# %% [markdown]
# **Question 8.** : Mention one of the important research paper related to this framework. Namely, _deep learning of dynamical systems with the Koopman operator_. Explain shortly the reason of your choice.

# %% [markdown]
# We choosed to mention the following paper:
# ```bibtex
# Lusch, B., Kutz, J. N., & Brunton, S. L. (2018). Deep learning for universal linear embeddings of nonlinear dynamics. Nature communications, 9(1), 4950.
# ```
#
# Along several other papers published around 2017 and 2018, it is one of the founding papers that introduced deep learning in the Koopman operator framework. The authors show that the Koopman operator can be learned using deep learning techniques, and that the Koopman operator can be used to learn the dynamics of a system from data. It is a highly cited paper, with more that 1000 citations.

# %% [markdown]
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**
